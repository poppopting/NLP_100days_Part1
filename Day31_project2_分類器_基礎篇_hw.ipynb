# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train.head()
# Out:
#    index class                      title
# 0      0    體育   亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1      1    體育  9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2      2    體育       如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3      3    體育      超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4      4    體育    騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('D07data')
pos = POS('D07data')

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):

    word_s = ws([title], sentence_segmentation=True)
    word_p = pos(word_s)
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(IntProgress(value=0, max=1800), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    word_s = ws([title], sentence_segmentation=True)
    word_p = pos(word_s)
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(IntProgress(value=0, max=600), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
idx = 0
for word_pos_list in train_title_cuts.values():
    for word, _ in word_pos_list:
        if word not in word2index:
            word2index[word] = idx
            index2word[idx] = word
            idx += 1

# %%
word2index['溫暖']
# Out:
# 1512

# %%
index2word[1512]
# Out:
# '溫暖'

# %%
def get_bow_vector(pairs, word2index):
    vector = np.zeros(len(word2index))
    for word, _ in pairs:
        if word in word2index:
            vector[word2index[word]] += 1
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['U23', '拉基蒂奇', '昂科威', '馬克', '多浪', '卡納瓦羅', '林斌', '安卓', '索尼', '清華', '郭躍', '許昕', '哈希', '遼足', '郭煒煒', '小白', '詹', '騰訊', '伯德', '馬化騰', '溫氏', '克洛普', '庫里', '巔峰賽', '阿里', '凱塔', '中金', '德羅', '浦發', '阿迪薩亞', '韓長賦', '國六', '萊昂納德', '重渡溝', '高曉松', '寶二', '韓信', '余則成', '樂福', '華為', 'J羅', '李白', '朱', '拜仁續', '亨德森', '宋鴻兵', '溫格', '伊亞', '聯發科', '王', '網傳', '·龜茲', '本澤馬', '武當', '林員', '亞特拉斯賽', '微星', '馬夏爾', '劉偉', '單薇恩', '王楚欽', '高傭', '拳皇', '小明', '查理芒格', '每日', '曼薩諾', '金秀瑤族', '網易', '萬孚', '陰陽師', '雀巢', '維特爾', '綠心', '華峰', '四阿哥', '建聯', '李謹詺', '納米 華', '纏中', '朱嘯虎', '張大仙', '威廉姆斯', '劉代全', '維亞利', '宇通', '科勒·卡戴珊', '綠軍', '霍金斯', '維韋杜詹霍', '舒斯特爾', '樸泰夏', '黃希揚', '木歷', '泰山', '馬龍', '后羿', 'S10', 'S11', '泰拳王西']
# =======================
# Na : ['泡沫', '網貸', '韭菜', '上聯', '生活', '事情', '美食', '芝麻', '變化', '門道', '梭', '文化', '路集', '壟通', '生態環境', '位置', '虧損', '冠', '物價', '帝王蟹', '漫畫', '級', '措施', '莊園', '要點', '遊戲', '同行', '紅酒', '痢疾', '證券', '空地', '星陣', '舉措', '球技', '主播', '火焰', '段位', '視點', '紙價', '外媒', '博會', '夢符祭', '內幕', '戰', '季賽', '板', '主義', '榮耀', '隊友', '買賣盤', '橋段', '情緒', '中小盤', '新高', '資管', '小兵', '工程', '老農', '戰火箭', '人次', '大小盤', '職位', '熱點', '生死', '九年制', '球王', '預算', '工程師', '彈幕', '理事會', '冠難', '少女', '人面', '瓜棚', '高峰', '空單', '鋼筋', '花卉', '白色', '所在', '商業', 'SWITCH版', '用', '動向', '野螳螂', '人氣', '人', '部位', '日乒', '能力', '陪襯品', '分析', '工資', '山東魯能', '農業', '名片', '小微', '大掃帚', '含金量', '方塊']
# =======================
# COLONCATEGORY : [':', '：']
# =======================
# Nc : ['京城', '陳倉', '東城', '希臘', '陸家嘴', '延邊', '周莊', '英國', '蒼穹', '球館', '果園', '天堂', '浩特', '中行', '鄉村', '湘西', '淡路島', '機場', '中', '南非', '吉爾吉斯斯坦', '納米比亞', '優區', '巨蛋', '河北', '海景驛站', '華', '大荔縣', '亞洲', '遵義市', '長白山', '崇義', '貴州省', '古鎮', '陝西', '外地', '遼寧省', '馬略卡島', '南粵', '港', '華中區', '山東', '湖南省', '下路', '寶里', '西里', '重慶', '華山', '鎮', '江西', '盧氏縣', '游古北', '以色列', '洛陽', '吐魯番', '影視城', '宿城', '幻想鄉', '下轄縣', '青島鄉', '校', '里貝里', '基地', '海南', '石家莊', '泰安', '鄭州', '茶鄉', '荒野', '山海', '信訪局', '東北', '窗口', '深圳', '西藏', '廣安', '火車站', '黃鶴樓', '中歐', '田野', '西安比', '交界', '免稅店', '牛場', '孟津', '上川島', '曼城', '福建', '東南亞', '場', '耿店村', '自駕游', '天際', '沂水', '北海道', '台南', '俄羅斯', '桂林', '袁家村', '河南']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['開戰', '加工', '鍍金', '退貨', '解惑', '罵屌絲', '復仇', '定位', '護航', '鋪平', '助威', '退改', '退款', '解體', '拍照', '再見', '罰款', '解密', '導航', '充飢', '計算出來', '提前', '領銜', '分組', '效力', '加起來', '執教', '站台', '一網打盡', '騙錢', '扣分', '融資', '充氣', '相比', '抓來', '加油', '分紅', '解圍', '加冕', '入賬', '通話', '分段', '上架', '代打', '收回來', '加持', '應對']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['所', '常常', '一直', '隨', '可能', '凌空', '親自', '別', '經常', '還', '自', '隨地', '好在', '總會', '逐漸', '一', '還是', '本來', '本', '未', '變相', '略', '竟然', '首先', '已', '從中', '當下', '沒', '也', '互相', '能否', '偶爾', '可', '帶頭', '總', '超級', '真是', '甚至', '白', '全力', '絕對', '皆', '常', '總是', '必須', '陸續', '隨時', '反野', '曾', '盡快', '有沒有', '玩絕', '居然', '該', '突然', '未必', '連', '雙雙', '竟', '仍然', '從來', '很少', '無可', '真的', '年年', '搞不好', '驟然', '多多少少', '究竟', '沒有', '大力', '越', '更', '終', '屢次', '完全', '首', '頻', '每', '那麼', '只有', '仍', '預先', '不要', '一定', '有', '為何', '多', '實在', '新', '能', '聯合', '都', '攜手', '老是', '初', '無法', '差點兒', '必然', '怎麼']
# =======================
# P : ['臨', '遭', '隨', '除了', '隨了', '對', '自', '直至', '距離', '因', '按', '跟', '把', '當', '慘遭', '往', '針對', '趁', '用', '幫', '就', '和', '至', '受', '將', '根據', '向', '除', '待', '在', '從', '比如', '趁著', '像', '如', '關於', '以', '於', '為了', '給', '為', '被', '自從', '與', '靠', '比', '繼', '離', '到', '憑', '等']
# =======================
# VG : ['合成', '形成', '投票成', '成', '當上', '非', '化', '排', '稱得上', '理解為', '類似', '當', '叫做', '排名', '封號', '集成', '升任', '名叫', '充當', '屈居', '算是', '屬於', '做', '猶如', '姓', '等於', '竟是', '變成', '美成', '像', '誤認成', '稱作', '當作', '彷彿', '堪稱', '當成', '賣成', '如', '改造成', '變', '作為', '成為', '為', '任', '稱為', '居', '泛濫成', '譽為', '排行', '應聘', '並列', '建成', '叫', '疑似', '做成', '算', '酷似', '稱', '評選', '戰成', '似']
# =======================
# Neu : ['兩萬', '萬億', '1200億', '1.8億', '85', '30', '1099', '91', '一', '135', '1000萬', '4', '2400', '1000', '010', '4000', '05-06 ', '1699', '1.46億', '4萬多', '億', '600', '400萬', '幾', '20萬一', '17億', '2萬', '22', '5.5', '13', '730萬', '三百', '1億', '第七', '47億', '3-1', '20萬', '十萬', '百萬', '十幾', '4000萬', '46萬', '4.5億', '4.5', '32', '300', '七', '5.7', '11.59億', '第1', '1', '幾千', '24億', '一千', '0', '甲', '54', '711', '一500', '25', '2000萬', '第3', '第二', '二〇三', '9', '1300', '21', '（二）', '七八千', '五一', '三十二', '100多', '64', '2599', '36萬', '6800', '60萬', '9-0', '35萬', '845', '980', '1-2', '98', '5050', '50萬', '450億', '1300萬', '56', '千億', '13888', '二十', '萬', '500萬', '1.1.2', '6.9', '九', '第三', '8萬', '三', '十六']
# =======================
# Nf : ['所', '班', '頁', '碗', '本', '把', '門', '只', '張', '路', '頓', '支', '條', '筆', '片', '隊', '棵', '級', '台', '個', '週', '輛', '層', '位', '色', '關', '槍', '遍', '件', '年', '點', '道', '鍋', '方', '毛', '句', '對', '座', '號', '番', '串', '分', '篇', '輪', '群', '塊', '項', '頭', '行', 'K', '港元', '胎', '批', '米', '款', '節', '回', '英吋', '盤', '些', '次', '畝', '株', '名', '場', '套', '招', '局', '屆', '歲', '日', '掛', '票', '袋', '類', '期', '噸', '周', '晚', '斤', '刻', '股', '元', '隻', '公里', '度', '戶', '處', '則', '部', '口', '家', '美元', '種', '分鐘', '樣', '秒', '檔', '步', '天']
# =======================
# VJ : ['優於', '超過', '逾', '認', '發生', '維持', '自有', '恭喜', '降至', '適用', '不到', '錯失', '仇', '恪守', '沒', '出', '賽', '虧損', '煥發', '贏下', '歸', '缺少', '過完', '符合', '無', '贏得', '欣賞', '沈迷', '獲得', '擁有', '曬', '懼怕', '忘懷', '強過', '贊同', '領略', '高達', '靠', '透', '爆發', '看懂', '值', '脫', '服', '不敵', '入圍', '近', '負於', '沒有', '錯過', '持有', '曝限', '獲', '歸屬於', '達到', '翻倍', '受到', '分享', '限', '受', '緊缺', '遭遇', '晉級', '珍惜', '耗', '出於', '忽略', '大勝', '羨慕', '不如', '毫無', '含有', '忽視', '偏愛', '佔', '享受', '缺', '痛失', '衝', '減', '要價', '領跑', '得', '惹不起', '看不過去', '新增', '認識', '替代', '經歷', '輸掉', '不理', '熱心', '抗', '失', '為', '蘊藏', '心疼', '嫌棄', '納入', '適應']
# =======================
# VD : ['支付', '拒賠', '予', '輸', '貸', '發給', '付', '郵給', '寄予', '還', '提供', '白送', '發放', '輸給', '售', '補繳', '贏', '借', '給予', '禁售', '搶', '分', '收費', '補貼', '速遞', '配', '清繳', '送', '借貸', '轉讓', '傳', '給', '賣', '欠', '貸款', '供應', '坑', '交付', '發']
# =======================
# Dfa : ['非常', '遠遠', '比較', '還', '頗', '較', '極', '還要', '有點', '有些', '更', '更為', '太', '多', '這麼', '好', '最', '同樣', '遠', '很', '十分', '過於', '超', '越來越', '不大', '如此', '過']
# =======================
# VH : ['雄厚', '好意', '嚴厲', '極好', '撲朔迷離', '利', '面世', '絕殺', '閃現', '這樣', '頂尖', '活', '繽紛', '可怕', '仿真', '犀利', '好好', '清淨', '爆炸', '不同', '不足', '開局', '好禮', '險勝', '缺席', '好看', '黃', '肺腑獨白', '不對勁', '固定', '破產', '成長', '耐人尋味', '尷尬', '色綠', '升級', '沸騰', '高度', '切實', '出世', '獨立', '神秘', '貴', '沒用', '自由', '壞', '強硬', '爛', '和睦', '混亂', '虛', '爆爆', '老', '幸福', '無憂', '相對', '歡樂', '上榜', '平安好', '頻繁', '受傷', '多彩', '很少', '有名', '健', '近', '實用', '轉型', '全神貫注', '慘敗', '細', '冒雨', '漲停', '畢業', '紅', '清淡', '狂', '穿', '跌', '單身', '崛起', '斜', '心酸', '原創', '倉促', '瞭', '拔涼拔涼', '詹吹', '遠', '怎麼', '保溫', '怎麼樣', '遲滯', '逼格', '低開', '甜蜜', '開幕', '夠', '強勢', '錯']
# =======================
# Cbb : ['因為', '並且', '不僅', '只要', '但', '即使', '因', '致', '假如', '既', '不管', '而', '否則', '跟著', '縱使', '只有', '只是', '但是', '不然', '可是', '不過', '還不如', '既然', '另外', '若', '雖然', '就算', '反而', '不如', '要是', '並', '如果', '而是', '連']
# =======================
# Nd : ['30號', '中旬', '昨天', '10點', '5號', '週末', '15日', '一會', '12日', '13點', '5月份', '昔日', '2035年', '未來', '5月', '5日', '季度', '明年', '晚清', '荒古', '半夜', '2019', '以後', '明日', '05月', '初夏', '相親節', '90年', '下旬', '採摘節', '一日', '23日', '夜', '隆慶', '季', '一下', '1點', '近日', '何時', '38+7', '最後', '狗年', '秋', '四月', '夏', '現代', '目前', '31號', '三國', '一大早', '今天', '4月', '晚間', '2020年', '幾月份', '多久', '今日', '夏季', '那時', '6旬', '永久', '目後', '雍正', '2018年', '春', '2018', '3月', '五月', '五月份', '月季', '2017年', '週二', '立夏', '旺季', '寒武紀', '2018年度', '早晨', '最近', '同時', '00年', '現在', '九月', '正月', '不久', '4日', '明晚', '當時', '七月份', '晚上', '今年', '以前', '米節', '過去', '中期', '周', '後來', '首日', '熱天', '旅遊節', '5.7日']
# =======================
# VA : ['產仔', '狩獵', '生活', '變身', '絕殺', '避暑', '上雙', '助攻', '唱歌', '大小便', '震蕩', '爭吵', '自駕', '代班', '掃碼', '開課', '跳', '健身', '哭', '餵尿素', '伸手', '出行', '花錢', '喧囂', '打板', '運營', '觀光', '掉幀', '徒步', '過閘', '保級', '降水', '落地', '逃亡', '攻堅', '表態', '參賽', '炒幣', '爭冠', '自殺', '加菜', '戰', '簽約', '坐穩', '開車', '備戰', '跌', '轟趴', '隕落', '養花', '造假', '升', '收尾', '探界', '開盤', '擒敵', '進去', '探案', '抗詹', '笑', '開店', '生財', '倒流', '自駕游', '養家糊口', '脫貧', '革命', '發家', '起航', '反轉', '競技', '挺進', '變陣', '會師', '違法', '下雪', '轉會', '跳舞', '打牌', '報名', '創業', '下馬', '打麻將', '工作', '充值', '連冠', '倒伏', '除權', '扣賬', '變盤', '砸盤', '加密', '漂流', '抓頂', '登高', '步行', '放飛', '壓哨', '出門', '發貨']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['何', '同', '前', '下', '首', '每', '頭', '貴', '各', '後', '某', '另', '該', '近', '本', '上']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# VC : ['防守', '斬落', '拍賣', '拿下', '揭密', '絕殺', '護', '認養', '縊縮', '防', '進出口', '邀請', '出口', '封禁', '宣', '挑', '花費', '體驗', '攝', '做', '通過', '中', '防控', '栽', '融合', '覲見', '前瞻', '擊敗', '列', '賣出', '包里', '炒', '綁定', '打掃', '誘', '釘釘', '建立', '發文', '追上', '學', '照看', '進口', '製作', '送別', '服', '酷開', '萌爆', '考察', '佔領', '喜迎', '耍', '展示', '放', '坐擁', '誤判', '踢', '管理', '保留', '分', '準備', '投入到', '參加', '穿', '面對', '搭配', '獨造', '指導', '蒙上', '打不過', '開出', '簽中', '擺出', '簽', '進化到', '提出', '刷到', '接', '守護', '打通', '變更', '留', '使用', '打贏', '挖', '撐', '取代', '提高', '比較', '制定', '收錄', '食用', '推出', '輔助', '避開', '揭秘', '嘗嘗', '起到', '用', '細看', '集中']
# =======================
# EXCLAMATIONCATEGORY : ['!', '！']
# =======================
# Di : ['個', '著', '起來', '過', '了']
# =======================
# Nep : ['這', '其中', '其', '哪', '啥', '那', '此', '什麼']
# =======================
# Caa : ['或是', '與', '及', '至', '或', '暨', '或者', 'VS', '比', '到', '和', '又', '跟', '還是']
# =======================
# VCL : ['前往', '重返', '穿透', '度過', '跌至', '登陸', '走下', '走訪', '穿過', '回歸', '升至', '去', '退出', '走進', '栽進', '蒞臨', '回', '用於', '往', '赴', '出發到', '遠離', '抵達', '路過', '出', '遊覽', '暗渡', '來到', '盤踞', '重回', '在', '直達', '走過', '玩遍', '跌出', '留在', '進', '到達', '入', '穿越', '深入', '存進', '橫掃', '住', '回到', '進入', '到', '前來', '上', '走到', '過']
# =======================
# Neqa : ['半', '句句', '8%', '那些', '20%', '三分之一', '0.8%', '一半', '有的', '步步', '部分', '9.89%', '其它', '有些', '百分之八十', '10%', '一些', '很多', '30%', '個個', '這麼多', '41.8%', '不少', '90%', '多', '全', '6%', '15%', '這些', '大多', '所有', '大量', '更多', '無數', '67%', '多點', '滴滴', '100%', '任何', '1/4', '1%', '四成', '哪些', '其他', '一處處', '遍', '一點', '多少', '12%', '一切', '80%', '大多數', '許多']
# =======================
# Nh : ['各自', '屌絲', '大家', '它們', '俺們', '自我', '人家', '她', '你', '各位', '一方', '我', '私人', '本人', '他', '您', '她們', '小眾', '你們', '它', '個人', '我們', '雙方', '誰', '別人', '父子倆', '自身', '自己', '他們', '對方']
# =======================
# FW : ['iPhone X', 'U23', 'G+', 'Credo', 'CDR', 'mAh+', 'CP', 'iPhone X Plus', ' VS ', 'LSPL', 'cpu', 'mix2', ' 秀', '6 10.5', 'MARVEL X', 'OB', 'GoogleI/O2018', 'SSR', '/', 'DNF', 'QQ', 'SIo', 'X13', 'kpl', 'Instagram', 'vip', 'Q', 'Khan', 'CCR', 'lck', 'BCH', 'CF', 'AI', 'DNF ', ' MDL', 'CFPL', 'King James', 'EVO', 'raid', 'Fullestop', 'One', 'BAT', 'PK', 'steam', 'iphone6plus', 'dnf', 'ios', ' vs 利物浦', 'Soloking', 'ABCC', 'CBA', 'max2', 'lol', 'AP', 'iPhone7', 'Day', 'VR', 'NPC', 'OPPO R', '4H', 'shou', 'GDP', 'FF ', 'SSG', 'cba', 'AD', 'QM', 'VR ', 'KPL', '+', 'B', 'IP', ' 比', 'mc', ' 2017', 'Lol里', ' 28', '│', 'vs', 'DOTA2 MOD', 'WF.D', 'Aloha', 'UZI', 'Brian Kelly', '>', 'PS4/NS', 'CEO', 'e', 'msi', '―', 'K', '9A91', 'eStarPro vs WF.D', ' 樂', '~', 'CCTV5', ' CCR', 'Mc', 'QG', 'Disneyland']
# =======================
# SHI : ['像是', '是']
# =======================
# VE : ['設想', '公示', '預計', '提起', '介紹', '預期', '看看', '公認', '判斷', '警惕', '准', '談', '揭曉', '賭', '想', '檢測', '公告', '回答', '說', '公佈', '以為', '聽說', '聽', '聽到', '防止', '問', '盛贊', '禁止', '提猜', '證明', '深思', '爆料', '廣播', '想要', '反對', '賭約', '見', '稱', '披露', '抱怨', '樂見', '見證', '商量', '查找', '精准', '做到', '呼籲', '估值', '宣佈', '管', '暗示', '形容', '幻想', '調研', '預防', '訴說', '提醒', '確認', '回顧', '考慮', '限制', '判定', '提', '探索', '申卡', '聊', '言', '看出', '鑒定', '要', '探討', '允許', '證', '看到', '安排', '預定', '承諾', '炫耀', '發誓', '想起', '算', '認為', '傳聞', '報道', '討說', '識別', '想到', '想好', '說明', '示範', '研究', '假設', '感嘆', '猜', '預告', '發佈', '判罰', '講解', '自嘲', '知詢']
# =======================
# DE : ['地', '之', '得', '的']
# =======================
# VHC : ['擴張', '減少', '規模化', '繁榮', '公開', '降低', '團結', '斷', '下來', '感動', '冷卻', '淡化', '還原', '變動', '停', '暫停', '傷', '國際化', '可憐', '滿足', '普及', '溫暖', '縮小', '穩定', '現代化', '寶智能化', '破', '辛苦', '熱', '強化', '產生', '增強', '增長', '煩', '壞', '優化', '肥', '增 ', '機構化', '平衡', '陷', '凍', '開', '震驚', '愁死', '加快', '麻煩', '恢復', '豐富', '增加', '結束', '愁壞', '告破']
# =======================
# Ng : ['以外', '之前', '以上', '以來', '左右', '般', '底', '下', '之中', '以下', '之間', '中', '外', '後', '之內', '裡', '初', '時', '之下', '為止', '來', '之外', '前', '間', '之後', '內', '以後', '之上', '上', '起']
# =======================
# VK : ['恨', '曲解', '同意', '回憶', '不忘', '感覺到', '理解', '欲', '意外', '期待', '忘', '面臨', '不滿', '忘記', '肯定', '懂得', '有利於', '喜歡', '懷疑', '擔心', '意想不到', '感謝', '感受', '感覺', '恐', '堅持', '顯示', '所謂', '流傳', '需', '希望', '介意', '覺得', '確定', '指望', '懂', '需要', '遇', '願', '覺', '害怕', '知道', '奇怪', '討厭', '怕', '小心', '放心', '依賴', '盼', '抱歉', '遺憾', '想見', '瞭解', '意味', '知', '願意', '注意', '信', '明白']
# =======================
# Ncd : ['對面', '方', '底部', '哪下', '那邊', '哪兒', '中間', '西部', '旁', '下', '當中', '東方', '以下', '裡面', '前沿', '東西部', '中', '畔', '東部', '邊', '那裡', '外', '末端', '裡', '中部', '上方', '哪裡', '間', '一帶', '上面', '東', '內', '哪', '這裡', '西', '上', '旁邊', '外面']
# =======================
# A : ['同等', '寶有', '母', '眾', '地下', '麻辣', '非', '火紅', '基層', '碧藍', '必備', '現役', '大幅度', '二手', '獨門', '一般', '現行', '重磅', '真正', '主', '獨角', '新興', '獨家', '最佳', '中', '彩色', '高度', '總', '超級', '業餘', '單', '國產', '多餘', '常務', '乒乓', '後置', '雙', '基礎', '前置', '唯一', '小本', '新一代', '歐式', '優質', '長途', '共同', '中西', '額外', '野生', '綜合', '上上', '原', '頭號', '超']
# =======================
# V_2 : ['有']
# =======================
# VL : ['令', '甘願', '致', '持續', '後悔', '使得', '讓', '用來', '愛好', '敢', '故意', '開始', '不惜', '能', '習慣', '導致', '便利', '使', '愛', '喜好', '趨於', '肯']
# =======================
# T : ['來', '的', '咯', '啊', '嗎', '嘛', '哦', '哪', '呢', '矣', '吧', '唄', '去', '麼', '啦', '了']
# =======================
# VI : ['驚艷', '著稱', '取勝', '專用']
# =======================
# DASHCATEGORY : ['-', '—']
# =======================
# I : ['瑪法里奧', '哦']
# =======================
# Dk : ['據聞', '外傳', '結果', '想不到', '那麼', '反過來', '那', '據說']
# =======================
# VF : ['逼', '請', '停止', '打算', '催', '試', '拒絕', '判', '圖', '勸住', '帶領', '申請', '準備', '勸說', '要求', '策劃', '擬', '率領', '鼓勵', '助', '告誡', '邀', '拒', '止住', '叫', '試試', '繼續', '推選']
# =======================
# Da : ['不下', '幾乎', '共', '僅', '將近', '最多', '足足', '正好', '光', '幾近', '近', '唯獨', '才', '約', '只']
# =======================
# PARENTHESISCATEGORY : ['「', '》', '（', '）', '《', '(', '」']
# =======================
# Nv : ['增發', '灌籃', '航海', '抗戰', '絕殺', '思考', '創業', '組合', '輔助', '生產', '工作', '回歸', '開發', '兼職', '研究', '錄制', '管理', '推薦', '私募', '判罰', '解救', '疊加', '度假', '安全', '批發', '分銷', '代理', '體驗', '射擊', '護髮', '翻譯', '問', '買單', '經歷', '登山', '旅遊', '供電', '配置', '燃燒', '訴訟', '關聯', '崩潰', '銷售', '營銷', '防治', '遊樂']
# =======================
# PERIODCATEGORY : ['·', '。']
# =======================
# VAC : ['蒸發', '動', '上演', '移動', '推進', '集合']
# =======================
# Dfb : ['一點', '夠', '極了', '些']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['以上', '半', '多']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        'Caa', 'Cab', 'Cba', 'Cbb',
        'Di', 'Dk', 'DM', 'I',
        'Nep', 'Ng', 'Nh', 'P', 'T', 'V_2', 'DE', 'SHI',
        'COLONCATEGORY', 'COMMACATEGORY', 'DASHCATEGORY', 'DOTCATEGORY', 'ETCCATEGORY', 'EXCLAMATIONCATEGORY',
        'PARENTHESISCATEGORY', 'PAUSECATEGORY', 'PERIODCATEGORY', 'QUESTIONCATEGORY', 'SEMICOLONCATEGORY',
        'SPCHANGECATEGORY', 'WHITESPACE'
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    len_bow1 = (bow1 **2).sum() **(1/2)
    len_bow2 = (bow2 **2).sum() **(1/2)
    similarity = np.sum(bow1*bow2) / (len_bow1*len_bow2)
    
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.00333333, 0.        , ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0., 0., 0., ..., 0., 0., 0.]),
#  '科技': array([0., 0., 0., ..., 0., 0., 0.]),
#  '旅遊': array([0., 0., 0., ..., 0., 0., 0.]),
#  '農業': array([0., 0., 0., ..., 0., 0., 0.]),
#  '遊戲': array([0.        , 0.        , 0.        , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 73, '遊戲': 10, '財經': 6, '農業': 6, '旅遊': 5, '科技': 3})
# predict 財經 :  Counter({'財經': 68, '科技': 21, '農業': 8, '遊戲': 6, '旅遊': 5, '體育': 4})
# predict 科技 :  Counter({'科技': 59, '財經': 14, '體育': 12, '農業': 5, '遊戲': 5, '旅遊': 2})
# predict 旅遊 :  Counter({'旅遊': 73, '農業': 9, '財經': 5, '科技': 2, '體育': 1, '遊戲': 1})
# predict 農業 :  Counter({'農業': 68, '旅遊': 9, '科技': 6, '財經': 4, '體育': 3, '遊戲': 2})
# predict 遊戲 :  Counter({'遊戲': 76, '科技': 8, '體育': 6, '旅遊': 5, '財經': 3, '農業': 3})
